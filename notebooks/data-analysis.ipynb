# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats

# %% [markdown]
# ## Data Analysis
#
# Set options to display all columns in pandas dataframe. Then import dataset and print its shape.
# After that we will visualize the data and remove ID column which is nothing but rown number.

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
data = pd.read_csv('../datasets/train.csv')
print(data.shape)
# Out:
# (1460, 81)

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.drop('Id', axis=1, inplace=True)
data.shape
# Out:
# (1460, 80)

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %% [markdown]
# ### Data distribution
#
# Now we will plot our dataset using histogram with 50 bins (divide data into 50 buckets) to show data distribution/skew.

# %%
# Exploring the target variable
data['SalePrice'].hist(bins=50, density=True)
plt.ylabel('Number of houses')
plt.xlabel('Sale Price')
plt.show()

# %% [markdown]
# We can see that data is skewed to the right (majority of values is on the left side of dataset). So let's try and use logarithmic transformation on target variable to see if we can get closer to Gaussian distribution as this is when models can yield better results.

# %%
np.log(data['SalePrice']).hist(bins=50, density=True)
plt.ylabel('Number of houses')
plt.xlabel('Sale Price')
plt.show()

# %% [markdown]
# Since we're getting more of gaussian distribution now we're going to use log values to predict the sales price going forward in the research and in modeling

# %% [markdown]
# ### Categorical vs Numerical variables

# %%
cat_cols = [i for i in data.columns if data[i].dtype == 'object']

# %% [markdown]
# By definition from data dict MSSubClass is also categorical so we will add to cat_cols and recast all categorical columns to 'object'

# %%
cat_cols += ['MSSubClass']
data[cat_cols] = data[cat_cols].astype('object')

# %%
num_cols = [i for i in data.columns if i not in cat_cols and i != 'SalePrice']

# %%
print(len(cat_cols), len(num_cols))
# Out:
# 44 35

# %% [markdown]
# ### Missing Values

# %%
cols_with_nulls = [i for i in data.columns if data[i].isnull().sum() > 0]
data[cols_with_nulls].isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
data[cols_with_nulls].isnull().mean().sort_values(ascending=False) # show % of missing values from total
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# MasVnrType      0.597260
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# BsmtFinType2    0.026027
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtCond        0.025342
# BsmtQual        0.025342
# MasVnrArea      0.005479
# Electrical      0.000685
# dtype: float64

# %%
data[cols_with_nulls].isnull().mean().sort_values(ascending=False).plot.bar(figsize=(10,4))
plt.ylabel('Percentage of missing data')
plt.axhline(y=0.90, color='r', linestyle='-')
plt.axhline(y=0.80, color='g', linestyle='-')
plt.show()

# %% [markdown]
# Let's check which columns that have missing values are categorical and which are numerical

# %%
cat_nulls = [i for i in cat_cols if i in cols_with_nulls]
num_nulls = [i for i in num_cols if i in cols_with_nulls]

# %%
cat_nulls
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
num_nulls
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
def analyse_na_value(df, var):

    # copy of the dataframe, so that we do not override the original data
    # see the link for more details about pandas.copy()
    # https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html
    df = data.copy()

    # let's make an interim variable that indicates 1 if the
    # observation was missing or 0 otherwise
    df[var] = np.where(df[var].isnull(), 1, 0)

    # let's compare the median SalePrice in the observations where data is missing
    # vs the observations where data is available

    # determine the median price in the groups 1 and 0,
    # and the standard deviation of the sale price,
    # and we capture the results in a temporary dataset
    tmp = df.groupby(var)['SalePrice'].agg(['mean', 'std'])

    # plot into a bar graph
    tmp.plot(kind="barh", y="mean", legend=False,
             xerr="std", title="Sale Price", color='green')

    plt.show()

# %%
# let's run the function on each variable with missing data

for var in cols_with_nulls:
    analyse_na_value(data, var)

# %% [markdown]
# ### Numerical variables

# %%
print('Numerical cols:', len(num_cols))
data[num_cols].head()
# Out:
# Numerical cols: 35
#    LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         65.0     8450            7            5       2003          2003
# 1         80.0     9600            6            8       1976          1976
# 2         68.0    11250            7            5       2001          2002
# 3         60.0     9550            7            5       1915          1970
# 4         84.0    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0       196.0         706           0        150          856       856
# 1         0.0         978           0        284         1262      1262
# 2       162.0         486           0        434          920       920
# 3         0.0         216           0        540          756       961
# 4       350.0         655           0        490         1145      1145
#
# ...

# %%
# Temporal variables
year_vars = [i for i in num_cols if 'Yr' in i or 'Year' in i]
year_vars
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for var in year_vars:
    print(var, data[var].unique())
    print()
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
#
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
#
# ...

# %%
data.groupby('YrSold')['SalePrice'].median().plot()
plt.ylabel('Median sales Price')
# Out:
# Text(0, 0.5, 'Median sales Price')

# %% [markdown]
# ### Categorical data

# %%
print('Number of categorical variables: ', len(cat_cols))
# Out:
# Number of categorical variables:  44

# %%
data[cat_cols].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %% [markdown]
# Let's see how many unique values we have per variable (i.e. what is the cardinality of the variables)

# %%
data[cat_cols].nunique().sort_values(ascending=False).plot.bar(figsize=(12, 5))
# Out:
# <Axes: >

# %%
tmp = data.groupby('Street')['SalePrice'].count() / len(data)
print(tmp[tmp > 0.05].index)
# Out:
# Index(['Pave'], dtype='object', name='Street')

# %%
def calculate_rarity(df, column_name):
    """
    Calculate the rarity of each unique value in a specified column of a DataFrame.
    
    Parameters:
        df (pd.DataFrame): The DataFrame containing the data.
        column_name (str): The name of the column for which rarity needs to be calculated.
        
    Returns:
        pd.DataFrame: A DataFrame containing the unique values, their counts, and rarity percentages.
    """
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in the DataFrame.")
    
    value_counts = df[column_name].value_counts().reset_index()
    value_counts.columns = [column_name, 'count']
    
    total_rows = len(df)
    value_counts['rarity_percentage'] = (value_counts['count'] / total_rows) * 100
    
    value_counts = value_counts.sort_values(by='rarity_percentage')
    
    return value_counts

# Example usage
rarity_df = calculate_rarity(data, 'Street')
print(rarity_df)
# Out:
#   Street  count  rarity_percentage
# 1   Grvl      6           0.410959
# 0   Pave   1454          99.589041

# %%
print([i for i in data['Street'].index if data['Street'][i] == 'Grvl'])
# Out:
# [52, 335, 582, 812, 1061, 1184]
